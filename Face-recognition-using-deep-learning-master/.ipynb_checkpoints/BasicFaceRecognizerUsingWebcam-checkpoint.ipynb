# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
  if model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])
  elif model.get_layer(name) != None:
    model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < 0.6:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
cam = cv2.VideoCapture(0)

face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from Dirk is 1.0602238
# Euclidean distance from jape is 0.8807326
# Euclidean distance from Kunal is 0.9722267
# Euclidean distance from Sumantra is 1.1459417
# Euclidean distance from User_9 is 0.921286
# Euclidean distance from Wanne is 0.55813336
# Euclidean distance from Dirk is 1.0662355
# Euclidean distance from jape is 0.8440566
# Euclidean distance from Kunal is 0.97639704
# Euclidean distance from Sumantra is 1.119904
# Euclidean distance from User_9 is 0.82234704
# Euclidean distance from Wanne is 0.5625297
# Euclidean distance from Dirk is 1.2137535
# Euclidean distance from jape is 0.8577794
# Euclidean distance from Kunal is 0.98564816
# Euclidean distance from Sumantra is 1.0893061
# Euclidean distance from User_9 is 0.8037825
# Euclidean distance from Wanne is 0.7037116
# Euclidean distance from Dirk is 1.1953255
# Euclidean distance from jape is 0.8993535
# Euclidean distance from Kunal is 0.99086356
# Euclidean distance from Sumantra is 1.0840738
# Euclidean distance from User_9 is 0.8692264
# Euclidean distance from Wanne is 0.70206994
# Euclidean distance from Dirk is 1.1490824
# Euclidean distance from jape is 1.076526
# Euclidean distance from Kunal is 1.1299952
# Euclidean distance from Sumantra is 0.8969013
# Euclidean distance from User_9 is 0.8942921
# Euclidean distance from Wanne is 0.86662984
# Euclidean distance from Dirk is 1.2359561
# Euclidean distance from jape is 0.9286868
# Euclidean distance from Kunal is 1.0548171
# Euclidean distance from Sumantra is 1.0751644
# Euclidean distance from User_9 is 0.8468385
# Euclidean distance from Wanne is 0.8069359
# Euclidean distance from Dirk is 1.1321274
# Euclidean distance from jape is 0.87642694
# Euclidean distance from Kunal is 0.9702821
# Euclidean distance from Sumantra is 1.1362801
# Euclidean distance from User_9 is 0.858305
# Euclidean distance from Wanne is 0.62578946
# Euclidean distance from Dirk is 1.220251
# Euclidean distance from jape is 0.80935496
# Euclidean distance from Kunal is 0.92993295
# Euclidean distance from Sumantra is 1.1022184
# Euclidean distance from User_9 is 0.7449222
# Euclidean distance from Wanne is 0.7034584
# Euclidean distance from Dirk is 1.2320117
# Euclidean distance from jape is 0.8618979
# Euclidean distance from Kunal is 0.98654723
# Euclidean distance from Sumantra is 1.0861025
# Euclidean distance from User_9 is 0.7631386
# Euclidean distance from Wanne is 0.7607502
# Euclidean distance from Dirk is 1.2377952
# Euclidean distance from jape is 0.89555997
# Euclidean distance from Kunal is 0.98376316
# Euclidean distance from Sumantra is 1.0225413
# Euclidean distance from User_9 is 0.79539055
# Euclidean distance from Wanne is 0.76679033
# Euclidean distance from Dirk is 1.2246097
# Euclidean distance from jape is 0.89502054
# Euclidean distance from Kunal is 0.96581626
# Euclidean distance from Sumantra is 1.0843356
# Euclidean distance from User_9 is 0.7852951
# Euclidean distance from Wanne is 0.76475596
# Euclidean distance from Dirk is 1.2173946
# Euclidean distance from jape is 0.87821287
# Euclidean distance from Kunal is 0.94625014
# Euclidean distance from Sumantra is 1.0524522
# Euclidean distance from User_9 is 0.7797223
# Euclidean distance from Wanne is 0.73494524
# Euclidean distance from Dirk is 1.2047507
# Euclidean distance from jape is 0.8721325
# Euclidean distance from Kunal is 0.9574893
# Euclidean distance from Sumantra is 1.0666025
# Euclidean distance from User_9 is 0.803067
# Euclidean distance from Wanne is 0.7039533
# Euclidean distance from Dirk is 1.2460302
# Euclidean distance from jape is 0.95555896
# Euclidean distance from Kunal is 1.0312165
# Euclidean distance from Sumantra is 1.0265014
# Euclidean distance from User_9 is 0.8987598
# Euclidean distance from Wanne is 0.7228312
# Euclidean distance from Dirk is 1.2562417
# Euclidean distance from jape is 0.90667206
# Euclidean distance from Kunal is 0.99202216
# Euclidean distance from Sumantra is 1.0614252
# Euclidean distance from User_9 is 0.8688418
# Euclidean distance from Wanne is 0.7521359
# Euclidean distance from Dirk is 1.1890124
# Euclidean distance from jape is 0.9557929
# Euclidean distance from Kunal is 1.0519754
# Euclidean distance from Sumantra is 1.1179544
# Euclidean distance from User_9 is 0.9412218
# Euclidean distance from Wanne is 0.73881984
# Euclidean distance from Dirk is 1.2425783
# Euclidean distance from jape is 0.9544402
# Euclidean distance from Kunal is 1.043552
# Euclidean distance from Sumantra is 1.0905617
# Euclidean distance from User_9 is 0.86252826
# Euclidean distance from Wanne is 0.7864449
# Euclidean distance from Dirk is 1.2289734
# Euclidean distance from jape is 0.99996036
# Euclidean distance from Kunal is 1.0702251
# Euclidean distance from Sumantra is 1.1251894
# Euclidean distance from User_9 is 0.9092189
# Euclidean distance from Wanne is 0.83349323
# Euclidean distance from Dirk is 1.1715496
# Euclidean distance from jape is 0.9836834
# Euclidean distance from Kunal is 1.0801984
# Euclidean distance from Sumantra is 1.0399212
# Euclidean distance from User_9 is 0.8468684
# Euclidean distance from Wanne is 0.8070465
# Euclidean distance from Dirk is 1.0706768
# Euclidean distance from jape is 0.9749776
# Euclidean distance from Kunal is 1.1229934
# Euclidean distance from Sumantra is 1.1697978
# Euclidean distance from User_9 is 0.9080172
# Euclidean distance from Wanne is 0.8063863
# Euclidean distance from Dirk is 0.9968797
# Euclidean distance from jape is 0.9486612
# Euclidean distance from Kunal is 1.0871061
# Euclidean distance from Sumantra is 1.2101843
# Euclidean distance from User_9 is 0.9127798
# Euclidean distance from Wanne is 0.72908646
# Euclidean distance from Dirk is 1.0584534
# Euclidean distance from jape is 0.9635176
# Euclidean distance from Kunal is 1.0986122
# Euclidean distance from Sumantra is 1.1539792
# Euclidean distance from User_9 is 0.8733587
# Euclidean distance from Wanne is 0.75171924
# Euclidean distance from Dirk is 0.9758649
# Euclidean distance from jape is 0.926356
# Euclidean distance from Kunal is 1.0423238
# Euclidean distance from Sumantra is 1.2216121
# Euclidean distance from User_9 is 0.90910333
# Euclidean distance from Wanne is 0.68966144
# Euclidean distance from Dirk is 1.3208079
# Euclidean distance from jape is 0.64118314
# Euclidean distance from Kunal is 0.81710124
# Euclidean distance from Sumantra is 1.1253419
# Euclidean distance from User_9 is 0.64379895
# Euclidean distance from Wanne is 0.75277054
# Euclidean distance from Dirk is 0.9997178
# Euclidean distance from jape is 0.878514
# Euclidean distance from Kunal is 0.97818685
# Euclidean distance from Sumantra is 1.1900402
# Euclidean distance from User_9 is 0.89738464
# Euclidean distance from Wanne is 0.6328379
# Euclidean distance from Dirk is 1.1383736
# Euclidean distance from jape is 0.9764803
# Euclidean distance from Kunal is 1.1250281
# Euclidean distance from Sumantra is 1.1941319
# Euclidean distance from User_9 is 0.90742415
# Euclidean distance from Wanne is 0.8439814
# Euclidean distance from Dirk is 1.0620452
# Euclidean distance from jape is 0.96833587
# Euclidean distance from Kunal is 1.077931
# Euclidean distance from Sumantra is 1.1651989
# Euclidean distance from User_9 is 0.889986
# Euclidean distance from Wanne is 0.74993515
# Euclidean distance from Dirk is 1.2353524
# Euclidean distance from jape is 0.9993215
# Euclidean distance from Kunal is 1.1066697
# Euclidean distance from Sumantra is 1.0716063
# Euclidean distance from User_9 is 0.8881085
# Euclidean distance from Wanne is 0.84131914
# Euclidean distance from Dirk is 1.2263485
# Euclidean distance from jape is 0.9096191
# Euclidean distance from Kunal is 1.0361137
# Euclidean distance from Sumantra is 1.0772965
# Euclidean distance from User_9 is 0.78213924
# Euclidean distance from Wanne is 0.79771036
# Euclidean distance from Dirk is 1.2228382
# Euclidean distance from jape is 0.79534525
# Euclidean distance from Kunal is 0.80588263
# Euclidean distance from Sumantra is 1.1529385
# Euclidean distance from User_9 is 0.8018363
# Euclidean distance from Wanne is 0.7105345
# Euclidean distance from Dirk is 1.1563804
# Euclidean distance from jape is 0.80718946
# Euclidean distance from Kunal is 0.94290245
# Euclidean distance from Sumantra is 1.0851165
# Euclidean distance from User_9 is 0.81328225
# Euclidean distance from Wanne is 0.6337601
# Euclidean distance from Dirk is 1.2395675
# Euclidean distance from jape is 0.72209436
# Euclidean distance from Kunal is 0.76711047
# Euclidean distance from Sumantra is 1.0729659
# Euclidean distance from User_9 is 0.7190256
# Euclidean distance from Wanne is 0.6491057
# Euclidean distance from Dirk is 1.1719342
# Euclidean distance from jape is 0.75405353
# Euclidean distance from Kunal is 0.92055935
# Euclidean distance from Sumantra is 1.1705172
# Euclidean distance from User_9 is 0.8138858
# Euclidean distance from Wanne is 0.6587561
# Euclidean distance from Dirk is 1.3135405
# Euclidean distance from jape is 0.9849953
# Euclidean distance from Kunal is 1.0842305
# Euclidean distance from Sumantra is 1.0217348
# Euclidean distance from User_9 is 0.9202888
# Euclidean distance from Wanne is 0.85018796
# Euclidean distance from Dirk is 1.20274
# Euclidean distance from jape is 0.96548486
# Euclidean distance from Kunal is 1.0536641
# Euclidean distance from Sumantra is 1.0430176
# Euclidean distance from User_9 is 0.93574864
# Euclidean distance from Wanne is 0.7289798
# Euclidean distance from Dirk is 1.2233162
# Euclidean distance from jape is 0.94953007
# Euclidean distance from Kunal is 1.0343847
# Euclidean distance from Sumantra is 1.1339122
# Euclidean distance from User_9 is 0.92082506
# Euclidean distance from Wanne is 0.76596254
# Euclidean distance from Dirk is 1.2185978
# Euclidean distance from jape is 0.6948785
# Euclidean distance from Kunal is 0.7558146
# Euclidean distance from Sumantra is 1.1747565
# Euclidean distance from User_9 is 0.77043414
# Euclidean distance from Wanne is 0.70675296
# Euclidean distance from Dirk is 1.2366178
# Euclidean distance from jape is 0.9819379
# Euclidean distance from Kunal is 1.0722286
# Euclidean distance from Sumantra is 1.0123392
# Euclidean distance from User_9 is 0.96054953
# Euclidean distance from Wanne is 0.73627156
# Euclidean distance from Dirk is 1.2119646
# Euclidean distance from jape is 0.6215564
# Euclidean distance from Kunal is 0.8136009
# Euclidean distance from Sumantra is 1.1993421
# Euclidean distance from User_9 is 0.7675817
# Euclidean distance from Wanne is 0.6457506
# Euclidean distance from Dirk is 1.3073739
# Euclidean distance from jape is 0.99753785
# Euclidean distance from Kunal is 1.1125526
# Euclidean distance from Sumantra is 0.9952181
# Euclidean distance from User_9 is 0.92609525
# Euclidean distance from Wanne is 0.8440747
# Euclidean distance from Dirk is 1.301259
# Euclidean distance from jape is 1.0996649
# Euclidean distance from Kunal is 1.1471597
# Euclidean distance from Sumantra is 1.0498312
# Euclidean distance from User_9 is 1.0521007
# Euclidean distance from Wanne is 0.9380512
# Euclidean distance from Dirk is 1.2599275
# Euclidean distance from jape is 0.92818516
# Euclidean distance from Kunal is 1.0350498
# Euclidean distance from Sumantra is 1.0440933
# Euclidean distance from User_9 is 0.8832886
# Euclidean distance from Wanne is 0.8501785
# Euclidean distance from Dirk is 1.2036
# Euclidean distance from jape is 0.67818123
# Euclidean distance from Kunal is 0.8320004
# Euclidean distance from Sumantra is 1.1601301
# Euclidean distance from User_9 is 0.8012744
# Euclidean distance from Wanne is 0.65057546
# Euclidean distance from Dirk is 1.225663
# Euclidean distance from jape is 1.0038856
# Euclidean distance from Kunal is 1.091011
# Euclidean distance from Sumantra is 1.0934256
# Euclidean distance from User_9 is 0.962553
# Euclidean distance from Wanne is 0.8535971
# Euclidean distance from Dirk is 1.1190729
# Euclidean distance from jape is 0.90220505
# Euclidean distance from Kunal is 1.0158287
# Euclidean distance from Sumantra is 1.1847584
# Euclidean distance from User_9 is 0.93545
# Euclidean distance from Wanne is 0.77481705
# Euclidean distance from Dirk is 1.2159141
# Euclidean distance from jape is 0.9816322
# Euclidean distance from Kunal is 1.0759882
# Euclidean distance from Sumantra is 1.0992866
# Euclidean distance from User_9 is 0.9297494
# Euclidean distance from Wanne is 0.8323787
# Euclidean distance from Dirk is 1.2548165
# Euclidean distance from jape is 0.542716
# Euclidean distance from Kunal is 0.72087675
# Euclidean distance from Sumantra is 1.0953803
# Euclidean distance from User_9 is 0.74743855
# Euclidean distance from Wanne is 0.65990937
# Euclidean distance from Dirk is 1.2387899
# Euclidean distance from jape is 0.9858677
# Euclidean distance from Kunal is 1.0602157
# Euclidean distance from Sumantra is 1.1081107
# Euclidean distance from User_9 is 0.96102655
# Euclidean distance from Wanne is 0.81755066
# Euclidean distance from Dirk is 1.2079207
# Euclidean distance from jape is 0.90749675
# Euclidean distance from Kunal is 1.0191011
# Euclidean distance from Sumantra is 1.1310647
# Euclidean distance from User_9 is 0.92386025
# Euclidean distance from Wanne is 0.7355575
# Euclidean distance from Dirk is 1.2119635
# Euclidean distance from jape is 0.65795094
# Euclidean distance from Kunal is 0.78415143
# Euclidean distance from Sumantra is 1.1517411
# Euclidean distance from User_9 is 0.7802166
# Euclidean distance from Wanne is 0.56518316
# Euclidean distance from Dirk is 1.1923252
# Euclidean distance from jape is 0.99691534
# Euclidean distance from Kunal is 1.0837803
# Euclidean distance from Sumantra is 1.145848
# Euclidean distance from User_9 is 1.0218586
# Euclidean distance from Wanne is 0.7772595
# Euclidean distance from Dirk is 1.2922847
# Euclidean distance from jape is 1.0052527
# Euclidean distance from Kunal is 1.1039929
# Euclidean distance from Sumantra is 1.1093632
# Euclidean distance from User_9 is 1.0196548
# Euclidean distance from Wanne is 0.8638418
# Euclidean distance from Dirk is 1.1941768
# Euclidean distance from jape is 0.9145538
# Euclidean distance from Kunal is 1.0520966
# Euclidean distance from Sumantra is 1.1498654
# Euclidean distance from User_9 is 0.9959772
# Euclidean distance from Wanne is 0.71058834
# Euclidean distance from Dirk is 1.2464404
# Euclidean distance from jape is 0.9296301
# Euclidean distance from Kunal is 1.0801922
# Euclidean distance from Sumantra is 1.108215
# Euclidean distance from User_9 is 0.9531034
# Euclidean distance from Wanne is 0.7836015
# Euclidean distance from Dirk is 1.1946013
# Euclidean distance from jape is 0.90584004
# Euclidean distance from Kunal is 1.0533526
# Euclidean distance from Sumantra is 1.1347593
# Euclidean distance from User_9 is 0.9782939
# Euclidean distance from Wanne is 0.68836194
# Euclidean distance from Dirk is 1.2624475
# Euclidean distance from jape is 1.0090451
# Euclidean distance from Kunal is 1.1062354
# Euclidean distance from Sumantra is 1.0286713
# Euclidean distance from User_9 is 0.99834144
# Euclidean distance from Wanne is 0.80063766
# Euclidean distance from Dirk is 1.3109769
# Euclidean distance from jape is 1.0256913
# Euclidean distance from Kunal is 1.0844827
# Euclidean distance from Sumantra is 1.0585891
# Euclidean distance from User_9 is 0.959718
# Euclidean distance from Wanne is 0.871218
# Euclidean distance from Dirk is 1.1946653
# Euclidean distance from jape is 0.6395115
# Euclidean distance from Kunal is 0.74211085
# Euclidean distance from Sumantra is 1.1777353
# Euclidean distance from User_9 is 0.7542574
# Euclidean distance from Wanne is 0.65825486
# Euclidean distance from Dirk is 1.3289028
# Euclidean distance from jape is 1.0781057
# Euclidean distance from Kunal is 1.119976
# Euclidean distance from Sumantra is 1.0558224
# Euclidean distance from User_9 is 0.9854077
# Euclidean distance from Wanne is 0.91587955
# Euclidean distance from Dirk is 1.2382351
# Euclidean distance from jape is 1.1532903
# Euclidean distance from Kunal is 1.1702894
# Euclidean distance from Sumantra is 1.0249403
# Euclidean distance from User_9 is 1.0297121
# Euclidean distance from Wanne is 0.89870805
# Euclidean distance from Dirk is 1.2449888
# Euclidean distance from jape is 1.0675972
# Euclidean distance from Kunal is 1.1199597
# Euclidean distance from Sumantra is 1.0396482
# Euclidean distance from User_9 is 0.9899333
# Euclidean distance from Wanne is 0.8235915
# Euclidean distance from Dirk is 1.2691711
# Euclidean distance from jape is 1.1105441
# Euclidean distance from Kunal is 1.1239451
# Euclidean distance from Sumantra is 1.0535836
# Euclidean distance from User_9 is 1.0134082
# Euclidean distance from Wanne is 0.8611039
# Euclidean distance from Dirk is 1.2524091
# Euclidean distance from jape is 1.0725172
# Euclidean distance from Kunal is 1.1283683
# Euclidean distance from Sumantra is 1.0465896
# Euclidean distance from User_9 is 0.99803895
# Euclidean distance from Wanne is 0.81629354
# Euclidean distance from Dirk is 1.2226493
# Euclidean distance from jape is 1.1740471
# Euclidean distance from Kunal is 1.2266417
# Euclidean distance from Sumantra is 1.080083
# Euclidean distance from User_9 is 1.135142
# Euclidean distance from Wanne is 0.901752
# Euclidean distance from Dirk is 1.1877471
# Euclidean distance from jape is 1.0171326
# Euclidean distance from Kunal is 1.122853
# Euclidean distance from Sumantra is 1.0919211
# Euclidean distance from User_9 is 1.017535
# Euclidean distance from Wanne is 0.7763802
# Euclidean distance from Dirk is 1.1569221
# Euclidean distance from jape is 1.1715428
# Euclidean distance from Kunal is 1.2327216
# Euclidean distance from Sumantra is 1.1405694
# Euclidean distance from User_9 is 1.1355001
# Euclidean distance from Wanne is 0.9201293
# Euclidean distance from Dirk is 1.2468741
# Euclidean distance from jape is 1.0567799
# Euclidean distance from Kunal is 1.1282103
# Euclidean distance from Sumantra is 1.0604296
# Euclidean distance from User_9 is 1.0623649
# Euclidean distance from Wanne is 0.8799055
# Euclidean distance from Dirk is 1.2570227
# Euclidean distance from jape is 1.2091669
# Euclidean distance from Kunal is 1.2150079
# Euclidean distance from Sumantra is 1.0488005
# Euclidean distance from User_9 is 1.1252959
# Euclidean distance from Wanne is 0.97215444
# Euclidean distance from Dirk is 1.2264508
# Euclidean distance from jape is 0.97866493
# Euclidean distance from Kunal is 1.056232
# Euclidean distance from Sumantra is 1.0702481
# Euclidean distance from User_9 is 1.0040947
# Euclidean distance from Wanne is 0.77922034
# Euclidean distance from Dirk is 1.015578
# Euclidean distance from jape is 0.9115682
# Euclidean distance from Kunal is 1.0696818
# Euclidean distance from Sumantra is 1.2197421
# Euclidean distance from User_9 is 1.0240473
# Euclidean distance from Wanne is 0.6979014
# Euclidean distance from Dirk is 1.2279433
# Euclidean distance from jape is 1.1318463
# Euclidean distance from Kunal is 1.1608031
# Euclidean distance from Sumantra is 1.1044359
# Euclidean distance from User_9 is 1.1109526
# Euclidean distance from Wanne is 0.87494385
# Euclidean distance from Dirk is 1.219192
# Euclidean distance from jape is 1.08651
# Euclidean distance from Kunal is 1.1458642
# Euclidean distance from Sumantra is 1.11269
# Euclidean distance from User_9 is 1.0819906
# Euclidean distance from Wanne is 0.8407626
# Euclidean distance from Dirk is 1.1519343
# Euclidean distance from jape is 0.97799784
# Euclidean distance from Kunal is 1.0541596
# Euclidean distance from Sumantra is 1.1515895
# Euclidean distance from User_9 is 1.0625509
# Euclidean distance from Wanne is 0.7545788
# Euclidean distance from Dirk is 1.1908886
# Euclidean distance from jape is 1.0930803
# Euclidean distance from Kunal is 1.150562
# Euclidean distance from Sumantra is 1.0849055
# Euclidean distance from User_9 is 1.0668758
# Euclidean distance from Wanne is 0.8596428
# Euclidean distance from Dirk is 1.1879537
# Euclidean distance from jape is 1.0108304
# Euclidean distance from Kunal is 1.0382062
# Euclidean distance from Sumantra is 1.0137823
# Euclidean distance from User_9 is 0.9982721
# Euclidean distance from Wanne is 0.8108041
# Euclidean distance from Dirk is 1.1351609
# Euclidean distance from jape is 1.2884934
# Euclidean distance from Kunal is 1.2734091
# Euclidean distance from Sumantra is 1.042557
# Euclidean distance from User_9 is 1.2548617
# Euclidean distance from Wanne is 1.0159
# Euclidean distance from Dirk is 1.2688187
# Euclidean distance from jape is 1.0494772
# Euclidean distance from Kunal is 1.0243816
# Euclidean distance from Sumantra is 0.97964746
# Euclidean distance from User_9 is 1.029104
# Euclidean distance from Wanne is 0.87035376
# Euclidean distance from Dirk is 1.3432658
# Euclidean distance from jape is 1.0667893
# Euclidean distance from Kunal is 1.0555421
# Euclidean distance from Sumantra is 0.8650689
# Euclidean distance from User_9 is 1.0035274
# Euclidean distance from Wanne is 0.93288726
# Euclidean distance from Dirk is 1.3425595
# Euclidean distance from jape is 1.1357946
# Euclidean distance from Kunal is 1.1501373
# Euclidean distance from Sumantra is 0.93242013
# Euclidean distance from User_9 is 1.0011402
# Euclidean distance from Wanne is 0.9552799
# Euclidean distance from Dirk is 1.4000552
# Euclidean distance from jape is 1.2269477
# Euclidean distance from Kunal is 1.2683964
# Euclidean distance from Sumantra is 1.0219309
# Euclidean distance from User_9 is 1.0874777
# Euclidean distance from Wanne is 1.1173601
# Euclidean distance from Dirk is 1.3625022
# Euclidean distance from jape is 1.239915
# Euclidean distance from Kunal is 1.2229444
# Euclidean distance from Sumantra is 0.89296424
# Euclidean distance from User_9 is 1.1254257
# Euclidean distance from Wanne is 1.0819438
# Euclidean distance from Dirk is 1.3109108
# Euclidean distance from jape is 1.2752267
# Euclidean distance from Kunal is 1.2615274
# Euclidean distance from Sumantra is 0.9332713
# Euclidean distance from User_9 is 1.1591895
# Euclidean distance from Wanne is 1.0954636
# Euclidean distance from Dirk is 1.3182315
# Euclidean distance from jape is 1.414169
# Euclidean distance from Kunal is 1.3370726
# Euclidean distance from Sumantra is 0.95627123
# Euclidean distance from User_9 is 1.2672564
# Euclidean distance from Wanne is 1.2025096
# Euclidean distance from Dirk is 1.3635035
# Euclidean distance from jape is 1.3488376
# Euclidean distance from Kunal is 1.3622282
# Euclidean distance from Sumantra is 1.0231696
# Euclidean distance from User_9 is 1.2069334
# Euclidean distance from Wanne is 1.2069961
# Euclidean distance from Dirk is 1.2919309
# Euclidean distance from jape is 1.1483032
# Euclidean distance from Kunal is 1.1735078
# Euclidean distance from Sumantra is 0.8832691
# Euclidean distance from User_9 is 1.0630251
# Euclidean distance from Wanne is 1.0271362
# Euclidean distance from Dirk is 1.3194548
# Euclidean distance from jape is 1.2010694
# Euclidean distance from Kunal is 1.2106754
# Euclidean distance from Sumantra is 0.92252666
# Euclidean distance from User_9 is 1.0915653
# Euclidean distance from Wanne is 1.05041
# Euclidean distance from Dirk is 1.4380957
# Euclidean distance from jape is 1.3299093
# Euclidean distance from Kunal is 1.3298023
# Euclidean distance from Sumantra is 1.0034429
# Euclidean distance from User_9 is 1.157607
# Euclidean distance from Wanne is 1.2040622
# Euclidean distance from Dirk is 1.4014251
# Euclidean distance from jape is 1.2038903
# Euclidean distance from Kunal is 1.196045
# Euclidean distance from Sumantra is 0.93042946
# Euclidean distance from User_9 is 1.0629843
# Euclidean distance from Wanne is 1.0199845
# Euclidean distance from Dirk is 1.4301014
# Euclidean distance from jape is 1.2597529
# Euclidean distance from Kunal is 1.2634598
# Euclidean distance from Sumantra is 0.9527893
# Euclidean distance from User_9 is 1.0779438
# Euclidean distance from Wanne is 1.1093155
# Euclidean distance from Dirk is 1.3173004
# Euclidean distance from jape is 1.0637273
# Euclidean distance from Kunal is 1.1073794
# Euclidean distance from Sumantra is 0.9852857
# Euclidean distance from User_9 is 0.9972987
# Euclidean distance from Wanne is 0.8707441
# Euclidean distance from Dirk is 1.4305017
# Euclidean distance from jape is 1.2320219
# Euclidean distance from Kunal is 1.2256341
# Euclidean distance from Sumantra is 0.95133924
# Euclidean distance from User_9 is 1.0228006
# Euclidean distance from Wanne is 1.0574529
# Euclidean distance from Dirk is 1.3357408
# Euclidean distance from jape is 1.1669054
# Euclidean distance from Kunal is 1.167127
# Euclidean distance from Sumantra is 0.9822308
# Euclidean distance from User_9 is 1.0356127
# Euclidean distance from Wanne is 0.9563594
# Euclidean distance from Dirk is 1.2783092
# Euclidean distance from jape is 1.1487964
# Euclidean distance from Kunal is 1.2048842
# Euclidean distance from Sumantra is 1.0760688
# Euclidean distance from User_9 is 1.0413082
# Euclidean distance from Wanne is 0.87462646
# Euclidean distance from Dirk is 1.312393
# Euclidean distance from jape is 1.0525271
# Euclidean distance from Kunal is 1.1757226
# Euclidean distance from Sumantra is 1.0837137
# Euclidean distance from User_9 is 0.9886918
# Euclidean distance from Wanne is 0.8624432
# Euclidean distance from Dirk is 1.3687335
# Euclidean distance from jape is 1.1168547
# Euclidean distance from Kunal is 1.1656606
# Euclidean distance from Sumantra is 1.014948
# Euclidean distance from User_9 is 0.99121886
# Euclidean distance from Wanne is 0.9328552
# Euclidean distance from Dirk is 1.1736773
# Euclidean distance from jape is 0.98355496
# Euclidean distance from Kunal is 1.1253101
# Euclidean distance from Sumantra is 1.0461123
# Euclidean distance from User_9 is 0.9767804
# Euclidean distance from Wanne is 0.70426947
# Euclidean distance from Dirk is 1.1798909
# Euclidean distance from jape is 0.82844526
# Euclidean distance from Kunal is 0.9710603
# Euclidean distance from Sumantra is 1.0353019
# Euclidean distance from User_9 is 0.80555546
# Euclidean distance from Wanne is 0.6081453
# Euclidean distance from Dirk is 1.3159014
# Euclidean distance from jape is 0.9801541
# Euclidean distance from Kunal is 1.1131049
# Euclidean distance from Sumantra is 1.0564092
# Euclidean distance from User_9 is 0.86897093
# Euclidean distance from Wanne is 0.83933204
# Euclidean distance from Dirk is 1.3040472
# Euclidean distance from jape is 0.8515988
# Euclidean distance from Kunal is 0.9665346
# Euclidean distance from Sumantra is 0.9617964
# Euclidean distance from User_9 is 0.7809651
# Euclidean distance from Wanne is 0.8487423
# Euclidean distance from Dirk is 1.20357
# Euclidean distance from jape is 0.869991
# Euclidean distance from Kunal is 0.9662923
# Euclidean distance from Sumantra is 0.8594995
# Euclidean distance from User_9 is 0.7351859
# Euclidean distance from Wanne is 0.77918625
